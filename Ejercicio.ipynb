# %% [markdown]
# <a href="https://colab.research.google.com/github/josedavidpazos/cos/blob/main/Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio:
#
# Después de acondicionar las señales ilustradas en el presente cuaderno, simule un proceso de discretización con Fs≥2Fo. Dibuje el resultado de la señal discretizada utilizando la función stem.
#
# Consultar el funcionamiento de los métodos cdist y argmin.
#
# Realice una función mediante el ambiente def que permita realizar los procesos de discretización y cuantización (usando cdist y argmin) en cascada para un conversor análogo-digital de 3 bits con entrada análoga de 0 a 10 [v]. Presente las gráficas de la señal original, señal con cero y pendiente, señal discretizada, y señal digital.

# %%
from numpy.core.multiarray import arange
import matplotlib.pyplot as plt
import numpy as np

K = 500 # número de muestras
f= 60
T_o = 1/f # periodo función sin
fs = 50*f
ts = 1/fs
A = 120 # amplitud
ti = 0 #tiempo inicial
tf = T_o #tiempo final
tv = np.arange(ti,tf,ts) #vector de datos en tiempo
xv = A * np.cos(2*np.pi*tv/T_o) #vector de amplitud

plt.stem(tv,xv, use_line_collection=True)
plt.show()
# Out:
# <ipython-input-2-7d5e4281c1e8>:16: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(tv,xv, use_line_collection=True)

# %%
cn=xv-np.min(xv)
cn=cn*(5/np.max(cn))

plt.stem(tv, cn, use_line_collection=True)
plt.show()
# Out:
# <ipython-input-3-877ba8cffcb4>:4: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(tv, cn, use_line_collection=True)
